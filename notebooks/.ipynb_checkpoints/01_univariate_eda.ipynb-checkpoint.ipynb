# %% [markdown]
# ### Customer behavior framework (RFM)
# #### Recency
# * How recently a customer made a purchase.
# * Example: Days_since_last_purchase
# #### Frequency
# * How often a customer interacts or purchases.
# * Example: Total_purchases, Login_frequency
# #### Monetary
# * How much value a customer contributes
# * Example: Lifetime_Value, Average_Order_Value

# %%
df[["Total_Purchases","Average_Order_Value","Lifetime_Value"]][df["Average_Order_Value"] > df["Lifetime_Value"]]
# Out:
#        Total_Purchases  Average_Order_Value  Lifetime_Value
# 296                1.0           230.500000      198.509995
# 492                1.0            77.500000       67.199997
# 534               13.0          5279.800781     1699.920044
# 1400               1.3           238.699997      237.660004
# 1771               0.0            68.260002        0.000000
# ...                ...                  ...             ...
# 38874             13.0          5467.298340     1274.209961
# 39243              1.0           137.990005      134.029999
# 39701              1.0            98.169998       84.629997
# 39929              1.0           149.419998      141.869995
# 39944              1.0           103.510002       92.800003
#
# [118 rows x 3 columns]

# %% [markdown]
# ##### So while mentioning about customer behavior framework, i noticed that
# * Certain records violate expected business relationships where Average_Order_Value exceeds Lifetime_Value
# * but the percentage is very low, which is 0.29% ~ 0.3%.
# * Given the very low occurrence rate, these records were retained while documenting the limitation as a potential synthetic data artifact.

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'City', 'Membership_Years',
#        'Login_Frequency', 'Session_Duration_Avg', 'Pages_Per_Session',
#        'Cart_Abandonment_Rate', 'Wishlist_Items', 'Total_Purchases',
#        'Average_Order_Value', 'Days_Since_Last_Purchase',
#        'Discount_Usage_Rate', 'Returns_Rate', 'Email_Open_Rate',
#        'Customer_Service_Calls', 'Product_Reviews_Written',
#        'Social_Media_Engagement_Score', 'Mobile_App_Usage',
#        'Payment_Method_Diversity', 'Lifetime_Value', 'Credit_Balance',
#        'Churned', 'Signup_Quarter'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from diptest import diptest

# %%
df = pd.read_csv(r"C:\Users\91891\Downloads\customer-churn-intelligence-system\data\model_data.csv")
df
# Out:
#         Age  Gender  Country         City  Membership_Years  Login_Frequency  \
# 0      36.0    Male       UK   Manchester               1.6             15.0
# 1      45.0  Female   Canada    Vancouver               2.9             10.0
# 2      56.0  Female      USA     New York               2.6             10.0
# 3      35.0    Male    Japan        Tokyo               3.5              6.0
# 4      56.0    Male  Germany       Berlin               1.9             24.0
# ...     ...     ...      ...          ...               ...              ...
# 39995  33.0    Male   France         Nice               4.5              6.0
# 39996  18.0  Female   France         Lyon               4.8              8.0
# 39997  38.0  Female      USA  Los Angeles              10.0             10.0
# 39998  37.0    Male      USA      Chicago               1.4             21.0
# 39999  44.0  Female      USA      Phoenix               2.8             19.0
#
#        Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                      42.7               10.3                   37.7
# 1                      24.8                1.6                   70.9
# 2                      38.4               14.8                   41.7
# 3                      21.9                6.9                   74.4
# 4                      46.4               13.9                   36.2
# ...                     ...                ...                    ...
# 39995                   NaN                6.9                   67.1
# 39996                  21.0                8.4                   69.5
# 39997                  35.8                8.8                   51.2
# 39998                  32.4                9.6                   32.5
# 39999                  40.3               10.4                   50.6
#
#        Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# 0                 1.0  ...             42.8                     7.0
# 1                 1.0  ...              0.0                     4.0
# 2                 9.0  ...             41.4                     2.0
# 3                 0.0  ...             16.0                     8.0
# 4                 5.0  ...             35.5                     4.0
# ...               ...  ...              ...                     ...
# 39995             2.0  ...              7.1                     8.0
# 39996             3.0  ...             17.4                     6.0
# 39997             3.0  ...              9.2                     5.0
# 39998             2.0  ...             17.6                     5.0
# 39999             1.0  ...             25.2                     4.0
#
#        Product_Reviews_Written  Social_Media_Engagement_Score  \
# 0                          3.0                            NaN
# 1                          1.0                            NaN
# 2                          5.0                           85.9
# 3                          2.0                           14.3
# 4                          6.0                           68.8
# ...                        ...                            ...
# 39995                      3.0                            3.2
# 39996                      5.0                           15.4
# 39997                      1.0                           20.7
# 39998                      3.0                           38.6
# 39999                      6.0                           59.9
#
#        Mobile_App_Usage  Payment_Method_Diversity  Lifetime_Value  \
# 0                  23.3                       3.0         1067.47
# 1                   8.8                       NaN         1289.75
# 2                  31.0                       3.0         2340.92
# 3                  11.2                       2.0         1995.43
# 4                  42.9                       5.0         3003.57
# ...                 ...                       ...             ...
# 39995              12.9                       5.0          917.83
# 39996              14.6                       2.0          813.11
# 39997              25.2                       1.0         2365.98
# 39998              12.1                       4.0         1293.60
# 39999               NaN                       1.0         1655.28
#
#        Credit_Balance  Churned  Signup_Quarter
# 0              3028.0        0              Q4
# 1              2317.0        0              Q4
# 2              2674.0        0              Q1
# 3              2418.0        1              Q1
# 4              2657.0        0              Q1
# ...               ...      ...             ...
# 39995          1298.0        1              Q4
# 39996          3565.0        1              Q2
# 39997          3499.0        0              Q2
# 39998          3154.0        0              Q3
# 39999          1622.0        0              Q1
#
# [40000 rows x 25 columns]

# %%
active_customers = df[df["Churned"] == 0]
active_customers
ui_data = active_customers.sample(10000, random_state = 42)
model_df = df.drop(ui_data.index)

# %%
model_df.to_csv(r"C:\Users\91891\Downloads\customer-churn-intelligence-system\data\model_data.csv",index=False)

# %%
ui_data = ui_data.drop(columns="Churned")

# %%
ui_data.to_csv(r"C:\Users\91891\Downloads\customer-churn-intelligence-system\data\company_data.csv",index=False)

# %%
df.memory_usage(deep=True).sum()

# np.int64(19148486) = bytes

# convert to mb use  # df.memory_usage(deep=True).sum() / 1024 ** 2
# Out:
# np.int64(19148486)

# %%
df.shape
# Out:
# (40000, 25)

# %%
df.head()
# Out:
#     Age  Gender  Country        City  Membership_Years  Login_Frequency  \
# 0  36.0    Male       UK  Manchester               1.6             15.0
# 1  45.0  Female   Canada   Vancouver               2.9             10.0
# 2  56.0  Female      USA    New York               2.6             10.0
# 3  35.0    Male    Japan       Tokyo               3.5              6.0
# 4  56.0    Male  Germany      Berlin               1.9             24.0
#
#    Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                  42.7               10.3                   37.7
# 1                  24.8                1.6                   70.9
# 2                  38.4               14.8                   41.7
# 3                  21.9                6.9                   74.4
# 4                  46.4               13.9                   36.2
#
#    Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# 0             1.0  ...             42.8                     7.0
# 1             1.0  ...              0.0                     4.0
# 2             9.0  ...             41.4                     2.0
# 3             0.0  ...             16.0                     8.0
# 4             5.0  ...             35.5                     4.0
#
#    Product_Reviews_Written  Social_Media_Engagement_Score  Mobile_App_Usage  \
# 0                      3.0                            NaN              23.3
# 1                      1.0                            NaN               8.8
# 2                      5.0                           85.9              31.0
# 3                      2.0                           14.3              11.2
# 4                      6.0                           68.8              42.9
#
#    Payment_Method_Diversity  Lifetime_Value  Credit_Balance  Churned  \
# 0                       3.0         1067.47          3028.0        0
# 1                       NaN         1289.75          2317.0        0
# 2                       3.0         2340.92          2674.0        0
# 3                       2.0         1995.43          2418.0        1
# 4                       5.0         3003.57          2657.0        0
#
#    Signup_Quarter
# 0              Q4
# 1              Q4
# 2              Q1
# 3              Q1
# 4              Q1
#
# [5 rows x 25 columns]

# %%
df.T
# Out:
#                                     0          1         2        3      \
# Age                                  36.0       45.0      56.0     35.0
# Gender                               Male     Female    Female     Male
# Country                                UK     Canada       USA    Japan
# City                           Manchester  Vancouver  New York    Tokyo
# Membership_Years                      1.6        2.9       2.6      3.5
# Login_Frequency                      15.0       10.0      10.0      6.0
# Session_Duration_Avg                 42.7       24.8      38.4     21.9
# Pages_Per_Session                    10.3        1.6      14.8      6.9
# Cart_Abandonment_Rate                37.7       70.9      41.7     74.4
# Wishlist_Items                        1.0        1.0       9.0      0.0
# Total_Purchases                      19.5        9.1      15.0     12.0
# Average_Order_Value                 82.45     165.52    147.33   190.97
# Days_Since_Last_Purchase             71.0       11.0      47.0     29.0
# Discount_Usage_Rate                 57.96      12.24      44.1     60.2
# Returns_Rate                          9.2       11.5       5.4     11.0
# Email_Open_Rate                      42.8        0.0      41.4     16.0
# Customer_Service_Calls                7.0        4.0       2.0      8.0
# Product_Reviews_Written               3.0        1.0       5.0      2.0
# Social_Media_Engagement_Score         NaN        NaN      85.9     14.3
# Mobile_App_Usage                     23.3        8.8      31.0     11.2
# Payment_Method_Diversity              3.0        NaN       3.0      2.0
# Lifetime_Value                    1067.47    1289.75   2340.92  1995.43
# Credit_Balance                     3028.0     2317.0    2674.0   2418.0
# Churned                                 0          0         0        1
# Signup_Quarter                         Q4         Q4        Q1       Q1
#
#                                  4        5        6        7        8      \
# Age                               56.0     32.0     32.0     40.0     18.0
# Gender                            Male     Male   Female   Female   Female
# Country                        Germany       UK  Germany      USA      USA
# City                            Berlin  Glasgow   Munich  Phoenix  Phoenix
# Membership_Years                   1.9      0.9      0.6      7.1      3.1
# Login_Frequency                   24.0      0.0     11.0     10.0     13.0
# Session_Duration_Avg              46.4     12.3     12.1     19.2     26.1
# Pages_Per_Session                 13.9      2.9      5.6      7.0      8.9
# Cart_Abandonment_Rate             36.2     73.5     77.2     69.1     47.7
# Wishlist_Items                     5.0      0.0      0.0      6.0      2.0
# Total_Purchases                   20.0      5.0      5.0     10.0     11.0
# Average_Order_Value             169.58    118.0    78.88   123.99   107.58
# Days_Since_Last_Purchase          10.0     23.0     36.0     38.0      3.0
# Discount_Usage_Rate               27.8     46.2     72.0     59.0     22.9
# Returns_Rate                       5.5      5.1      4.8      1.9      0.2
# Email_Open_Rate                   35.5      0.0      4.0      9.6     19.0
# Customer_Service_Calls             4.0     11.0      7.0      4.0      8.0
# Product_Reviews_Written            6.0      2.0      1.0      NaN      4.0
# Social_Media_Engagement_Score     68.8     17.0      0.0     17.7      NaN
# Mobile_App_Usage                  42.9      8.0     17.7      NaN     21.5
# Payment_Method_Diversity           5.0      1.0      2.0      4.0      3.0
# Lifetime_Value                 3003.57   599.41   335.92  1229.94  1083.91
# Credit_Balance                  2657.0    498.0   1369.0   2446.0   2772.0
# Churned                              0        1        1        0        1
# Signup_Quarter                      Q1       Q2       Q3       Q1       Q3
#
#                                  9      ...     39990    39991     39992  \
# Age                               18.0  ...      37.0     63.0      44.0
# Gender                          Female  ...    Female   Female    Female
# Country                         France  ...       USA   Canada    France
# City                             Paris  ...  New York   Ottawa  Toulouse
# Membership_Years                   3.7  ...       5.4      6.6       4.5
# Login_Frequency                   14.0  ...      12.0     14.0       5.0
# Session_Duration_Avg              33.5  ...      31.1     32.0      22.4
# Pages_Per_Session                 10.3  ...       5.7     10.2       9.5
# Cart_Abandonment_Rate             48.4  ...      80.7     55.8      49.6
# Wishlist_Items                     2.0  ...       3.0      4.0       9.0
# Total_Purchases                   15.0  ...       8.0     20.0      11.0
# Average_Order_Value              123.0  ...    123.65   224.82     62.58
# Days_Since_Last_Purchase           8.0  ...      11.0     14.0      76.0
# Discount_Usage_Rate               40.0  ...      63.3     25.4      44.2
# Returns_Rate                       3.7  ...       2.2      2.2       4.9
# Email_Open_Rate                   16.1  ...       7.3     20.6      21.3
# Customer_Service_Calls             6.0  ...       4.0      2.0       7.0
# Product_Reviews_Written            4.0  ...       3.0      NaN       3.0
# Social_Media_Engagement_Score     28.3  ...      19.0     11.1       NaN
# Mobile_App_Usage                  23.3  ...      23.1     25.3      29.0
# Payment_Method_Diversity           3.0  ...       3.0      1.0       1.0
# Lifetime_Value                 1618.51  ...   1131.42  4366.63    601.74
# Credit_Balance                  3624.0  ...       0.0   3888.0    2201.0
# Churned                              0  ...         0        0         0
# Signup_Quarter                      Q1  ...        Q3       Q3        Q2
#
#                                  39993    39994   39995   39996        39997  \
# Age                               40.0     29.0    33.0    18.0         38.0
# Gender                            Male     Male    Male  Female       Female
# Country                             UK      USA  France  France          USA
# City                           Glasgow  Chicago    Nice    Lyon  Los Angeles
# Membership_Years                   4.0      4.9     4.5     4.8         10.0
# Login_Frequency                   15.0     12.0     6.0     8.0         10.0
# Session_Duration_Avg              12.7     40.1     NaN    21.0         35.8
# Pages_Per_Session                  8.1     10.2     6.9     8.4          8.8
# Cart_Abandonment_Rate             68.6     40.7    67.1    69.5         51.2
# Wishlist_Items                     2.0      9.0     2.0     3.0          3.0
# Total_Purchases                   14.3     15.6    10.4    16.0         13.0
# Average_Order_Value             220.66   128.26   97.24   51.86       156.76
# Days_Since_Last_Purchase          18.0      5.0    61.0    45.0         18.0
# Discount_Usage_Rate              60.84    39.48    9.84    25.6         62.7
# Returns_Rate                       4.2      9.7    14.5    18.8          NaN
# Email_Open_Rate                   15.0     12.6     7.1    17.4          9.2
# Customer_Service_Calls            10.0      3.0     8.0     6.0          5.0
# Product_Reviews_Written            1.0      4.0     3.0     5.0          1.0
# Social_Media_Engagement_Score     17.7     51.3     3.2    15.4         20.7
# Mobile_App_Usage                   NaN     25.6    12.9    14.6         25.2
# Payment_Method_Diversity           1.0      3.0     5.0     2.0          1.0
# Lifetime_Value                 2196.96  1257.02  917.83  813.11      2365.98
# Credit_Balance                   928.0      0.0  1298.0  3565.0       3499.0
# Churned                              1        0       1       1            0
# Signup_Quarter                      Q4       Q4      Q4      Q2           Q2
#
#                                  39998    39999
# Age                               37.0     44.0
# Gender                            Male   Female
# Country                            USA      USA
# City                           Chicago  Phoenix
# Membership_Years                   1.4      2.8
# Login_Frequency                   21.0     19.0
# Session_Duration_Avg              32.4     40.3
# Pages_Per_Session                  9.6     10.4
# Cart_Abandonment_Rate             32.5     50.6
# Wishlist_Items                     2.0      1.0
# Total_Purchases                   15.0     12.0
# Average_Order_Value             103.31   139.44
# Days_Since_Last_Purchase          48.0      7.0
# Discount_Usage_Rate               66.3      NaN
# Returns_Rate                       NaN     10.7
# Email_Open_Rate                   17.6     25.2
# Customer_Service_Calls             5.0      4.0
# Product_Reviews_Written            3.0      6.0
# Social_Media_Engagement_Score     38.6     59.9
# Mobile_App_Usage                  12.1      NaN
# Payment_Method_Diversity           4.0      1.0
# Lifetime_Value                  1293.6  1655.28
# Credit_Balance                  3154.0   1622.0
# Churned                              0        0
# Signup_Quarter                      Q3       Q1
#
# [25 rows x 40000 columns]

# %%
# so email open rate - how will the company knows whether we opened the email or not,
# they will attach a small image, so whenever we open the mail that image loads form the server
# then server records the email was opened.
# Since the credit balance values are relatively low and consistent with ecommerce transactions, this feature likely represents store credit or wallet balance rather than outstanding debt.
# cohort behavior

# columns
# age - age of the customers
# gender - gender of the customers
# country - country of the customer residence
# City - city of the customer
# Membership_Years - Number of years the customer has been a member of the platform
# Login_Frequency - Average number of logins per month
# Session_Duration_Avg - Average session duration in minutes, in one session 
# Pages_Per_Session - Average of how many pages customer viewed per session
# Cart_Abandonment_Rate - percentage of the abandoned carts in the sessions
# ex 
# session -   Action
# 1       -   Adds x items to cart
# 2       -   Buys x items from cart
# 3       -   Adds x items to cart
# number of times carts created - number of times bought a item(buys) / number of times carts created
# (3 - 1) / 3 = 0.66
# Wishlist_Items - Number of items in customer's wishlist
# Total_Purchases - 
# Average_Order_Value - Average value per order in currency units
# Days_Since_Last_Purchase - Number of days since most recent purchase
# Discount_Usage_Rate - Percentage of purchases using discounts
# Returns_Rate - Percentage of items returned
# Email_Open_Rate - Percentage of marketing emails opened
# the company people will use a small image while sending the mail, whenever a customer opens that mail, it gets notified in the server.
# Customer_Service_Calls - number of times the customer made customer calls.
# Product_Reviews_Written - Number of product reviews submitted
# Social_Media_Engagement_Score - Social media interaction score (0-100)
# Mobile_App_Usage - can also use website, so here it only focuses on activity from mobile app
# Payment_Method_Diversity - Number of different payment methods used
# Lifetime_Value - Total customer lifetime value in currency units - LTV = Sum of all purchases made by customer
# Credit_Balance - store credit or wallet balance
# Churned - target col - 1 - churned and 0 is not churned
# Signup_Quarter - in which quarter they started using our site, sometimes customers uses our website when sale is there, in that way

# %%
df[["Total_Purchases","Average_Order_Value"]]
# Out:
#        Total_Purchases  Average_Order_Value
# 0                 19.5                82.45
# 1                  9.1               165.52
# 2                 15.0               147.33
# 3                 12.0               190.97
# 4                 20.0               169.58
# ...                ...                  ...
# 39995             10.4                97.24
# 39996             16.0                51.86
# 39997             13.0               156.76
# 39998             15.0               103.31
# 39999             12.0               139.44
#
# [40000 rows x 2 columns]

# %%
class MemoryOptimizer():
    def __init__(self,df):
        self.df = df
        self.bool_type = []
        self.int_type = []
        self.float_type = []
        self.object_type = []
        self.category_type = []
        self.datetime = []
        self.threshold = 0.2

    def detect_type(self):
        for col in self.df.columns:
            if pd.api.types.is_bool_dtype(self.df[col]):
                self.bool_type.append(col)
            elif pd.api.types.is_integer_dtype(self.df[col]):
                self.int_type.append(col)
            elif pd.api.types.is_float_dtype(self.df[col]):
                self.float_type.append(col)
            elif pd.api.types.is_object_dtype(self.df[col]):
                self.object_type.append(col)
            elif pd.api.types.is_categorical_dtype(self.df[col]):
                self.category_type.append(col)
            elif pd.api.types.is_datetime64_any_dtype(self.df[col]):
                self.datetime.append(col)
        return self.bool_type,self.int_type,self.float_type,self.object_type,self.category_type,self.datetime

    def optimize_object(self):
        size = len(self.df)
        for col in self.object_type:
            unique_count = len(self.df[col].value_counts())
            ratio = unique_count/size
            if ratio <= self.threshold:
                self.df[col] = self.df[col].astype("category")

    def optimize_numeric(self):
        for col in self.int_type:
            self.df[col] = pd.to_numeric(self.df[col], downcast="integer")
            
        for col in self.float_type:
            # if float values are not actual
            temp_col = self.df[col].dropna()
            
            if (temp_col % 1 == 0).all():
                if self.df[col].isna().any():
                    temp_dtype = pd.to_numeric(temp_col, downcast="integer").dtype
                    nullable_dtype = str(temp_dtype).replace("int","Int")
                    self.df[col] = self.df[col].astype(nullable_dtype)
                # if no nulls
                else:
                    self.df[col] = pd.to_numeric(self.df[col],downcast="integer")
            # if actual float values exist, keep float   
            else:
                self.df[col] = pd.to_numeric(self.df[col], downcast="float")
    

    def optimize(self):
        before = self.df.memory_usage(deep=True).sum() / 1024**2

        self.detect_type()
        self.optimize_object()
        self.optimize_numeric()

        after = self.df.memory_usage(deep=True).sum() / 1024**2
        print("Before memory:", round(before,2),"MB")
        print("After memory:", round(after,2),"MB")
        print("Reduced:", round((before-after) / before * 100,2),"%")
        return self.df

# %%
optimizer = MemoryOptimizer(df)
df = optimizer.optimize()
df.to_parquet(r"C:\Users\91891\Downloads\customer-churn-intelligence-system\data\optimized_df.parquet",index=False)
# Out:
# Before memory: 14.61 MB
# After memory: 2.71 MB
# Reduced: 81.43 %

# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-24.0.0-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Downloading pyarrow-24.0.0-cp312-cp312-win_amd64.whl (27.4 MB)
#    ---------------------------------------- 0.0/27.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/27.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/27.4 MB 989.2 kB/s eta 0:00:28
#    - -------------------------------------- 0.8/27.4 MB 1.0 MB/s eta 0:00:27
#    - -------------------------------------- 1.0/27.4 MB 986.7 kB/s eta 0:00:27
#    - -------------------------------------- 1.3/27.4 MB 1.0 MB/s eta 0:00:26
#    -- ------------------------------------- 1.6/27.4 MB 1.2 MB/s eta 0:00:23
#    --- ------------------------------------ 2.1/27.4 MB 1.3 MB/s eta 0:00:20
#    --- ------------------------------------ 2.4/27.4 MB 1.3 MB/s eta 0:00:20
#    --- ------------------------------------ 2.6/27.4 MB 1.3 MB/s eta 0:00:19
#    ---- ----------------------------------- 2.9/27.4 MB 1.3 MB/s eta 0:00:19
#    ---- ----------------------------------- 3.4/27.4 MB 1.4 MB/s eta 0:00:17
#    ------ --------------------------------- 4.2/27.4 MB 1.5 MB/s eta 0:00:16
#    ------ --------------------------------- 4.5/27.4 MB 1.6 MB/s eta 0:00:15
#    ------- -------------------------------- 5.0/27.4 MB 1.7 MB/s eta 0:00:14
#    ------- -------------------------------- 5.2/27.4 MB 1.6 MB/s eta 0:00:14
#    --------- ------------------------------ 6.3/27.4 MB 1.8 MB/s eta 0:00:12
#    --------- ------------------------------ 6.8/27.4 MB 1.8 MB/s eta 0:00:12
#    ---------- ----------------------------- 7.1/27.4 MB 1.8 MB/s eta 0:00:12
#    ----------- ---------------------------- 7.9/27.4 MB 1.9 MB/s eta 0:00:11
#    ------------ --------------------------- 8.4/27.4 MB 1.9 MB/s eta 0:00:10
#    ------------- -------------------------- 8.9/27.4 MB 2.0 MB/s eta 0:00:10
#    -------------- ------------------------- 9.7/27.4 MB 2.0 MB/s eta 0:00:09
#    -------------- ------------------------- 10.0/27.4 MB 2.0 MB/s eta 0:00:09
#    --------------- ------------------------ 10.7/27.4 MB 2.1 MB/s eta 0:00:09
#    ---------------- ----------------------- 11.3/27.4 MB 2.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 11.8/27.4 MB 2.1 MB/s eta 0:00:08
#    ------------------ --------------------- 12.3/27.4 MB 2.1 MB/s eta 0:00:08
#    ------------------ --------------------- 12.8/27.4 MB 2.2 MB/s eta 0:00:07
#    ------------------- -------------------- 13.6/27.4 MB 2.2 MB/s eta 0:00:07
#    -------------------- ------------------- 13.9/27.4 MB 2.2 MB/s eta 0:00:07
#    --------------------- ------------------ 14.4/27.4 MB 2.2 MB/s eta 0:00:06
#    --------------------- ------------------ 14.7/27.4 MB 2.2 MB/s eta 0:00:06
#    --------------------- ------------------ 14.9/27.4 MB 2.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 15.7/27.4 MB 2.2 MB/s eta 0:00:06
#    ----------------------- ---------------- 16.3/27.4 MB 2.2 MB/s eta 0:00:06
#    ------------------------ --------------- 16.8/27.4 MB 2.2 MB/s eta 0:00:05
#    ------------------------ --------------- 17.0/27.4 MB 2.2 MB/s eta 0:00:05
#    -------------------------- ------------- 17.8/27.4 MB 2.2 MB/s eta 0:00:05
#    --------------------------- ------------ 18.6/27.4 MB 2.2 MB/s eta 0:00:04
#    --------------------------- ------------ 19.1/27.4 MB 2.2 MB/s eta 0:00:04
#    ----------------------------- ---------- 19.9/27.4 MB 2.3 MB/s eta 0:00:04
#    ------------------------------ --------- 21.0/27.4 MB 2.3 MB/s eta 0:00:03
#    ------------------------------- -------- 21.8/27.4 MB 2.4 MB/s eta 0:00:03
#    -------------------------------- ------- 22.5/27.4 MB 2.4 MB/s eta 0:00:03
#    --------------------------------- ------ 23.1/27.4 MB 2.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 23.6/27.4 MB 2.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 24.4/27.4 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------ --- 25.2/27.4 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 26.0/27.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  26.7/27.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 27.4/27.4 MB 2.5 MB/s  0:00:11
# Installing collected packages: pyarrow
# Successfully installed pyarrow-24.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# here the age col is float value, if really that float matters, we will continue using that, else can convert to discrete
a = (df["Age"] % 1 !=0)
b = a[a==True]
len(b)
# so here the number of non discrete value are 2495 but they are NULL values
# so can convert to discrete
df["Age"].min()
df["Age"].max()
# Out:
# np.int16(200)

# %%
df["Age"].isna().sum()
# Out:
# np.int64(1957)

# %%
# df["Age"] = df["Age"].astype("int16") -  since there are null values we cant use this
df["Age"] = df["Age"].astype("Int16")  # this is an alternative for null value
# 2nd col gender - object, we can convert to category, as object stores whole string, 
# ex in object = ["female","male"] if male appears 1000 times, it stores 1000 times, which is a waste of memory
# so using category means it stores values like this ["female":0,"male":1] = ["female","male","male","female"] how it is stored is 
# categiry = ["female","male"]
# codes = [0,1,1,0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            38043 non-null  Int16
#  1   Gender                         40000 non-null  category
#  2   Country                        40000 non-null  category
#  3   City                           40000 non-null  category
#  4   Membership_Years               40000 non-null  float32
#  5   Login_Frequency                40000 non-null  int8
#  6   Session_Duration_Avg           37142 non-null  float32
#  7   Pages_Per_Session              37609 non-null  float32
#  8   Cart_Abandonment_Rate          40000 non-null  float32
#  9   Wishlist_Items                 36792 non-null  Int8
#  10  Total_Purchases                40000 non-null  float32
#  11  Average_Order_Value            40000 non-null  float32
#  12  Days_Since_Last_Purchase       37595 non-null  Int16
#  13  Discount_Usage_Rate            37234 non-null  float32
#  14  Returns_Rate                   36418 non-null  float32
#  15  Email_Open_Rate                37940 non-null  float32
#  16  Customer_Service_Calls         39869 non-null  Int8
#  17  Product_Reviews_Written        37182 non-null  Int8
#  18  Social_Media_Engagement_Score  35212 non-null  float32
#  19  Mobile_App_Usage               36016 non-null  float32
#  20  Payment_Method_Diversity       37997 non-null  Int8
#  21  Lifetime_Value                 40000 non-null  float32
#  22  Credit_Balance                 35566 non-null  Int16
#  23  Churned                        40000 non-null  int8
#  24  Signup_Quarter                 40000 non-null  category
# dtypes: Int16(3), Int8(4), category(4), float32(12), int8(2)
# memory usage: 2.7 MB

# %%
df[(df["Login_Frequency"] % 1 != 0)]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Country, City, Membership_Years, Login_Frequency, Session_Duration_Avg, Pages_Per_Session, Cart_Abandonment_Rate, Wishlist_Items, Total_Purchases, Average_Order_Value, Days_Since_Last_Purchase, Discount_Usage_Rate, Returns_Rate, Email_Open_Rate, Customer_Service_Calls, Product_Reviews_Written, Social_Media_Engagement_Score, Mobile_App_Usage, Payment_Method_Diversity, Lifetime_Value, Credit_Balance, Churned, Signup_Quarter]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#        Age  Gender  Country         City  Membership_Years  Login_Frequency  \
# 0       36    Male       UK   Manchester               1.6               15
# 1       45  Female   Canada    Vancouver               2.9               10
# 2       56  Female      USA     New York               2.6               10
# 3       35    Male    Japan        Tokyo               3.5                6
# 4       56    Male  Germany       Berlin               1.9               24
# ...    ...     ...      ...          ...               ...              ...
# 39995   33    Male   France         Nice               4.5                6
# 39996   18  Female   France         Lyon               4.8                8
# 39997   38  Female      USA  Los Angeles              10.0               10
# 39998   37    Male      USA      Chicago               1.4               21
# 39999   44  Female      USA      Phoenix               2.8               19
#
#        Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                 42.700001               10.3              37.700001
# 1                 24.799999                1.6              70.900002
# 2                 38.400002               14.8              41.700001
# 3                 21.900000                6.9              74.400002
# 4                 46.400002               13.9              36.200001
# ...                     ...                ...                    ...
# 39995                   NaN                6.9              67.099998
# 39996             21.000000                8.4              69.500000
# 39997             35.799999                8.8              51.200001
# 39998             32.400002                9.6              32.500000
# 39999             40.299999               10.4              50.599998
#
#        Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# 0                   1  ...        42.799999                       7
# 1                   1  ...         0.000000                       4
# 2                   9  ...        41.400002                       2
# 3                   0  ...        16.000000                       8
# 4                   5  ...        35.500000                       4
# ...               ...  ...              ...                     ...
# 39995               2  ...         7.100000                       8
# 39996               3  ...        17.400000                       6
# 39997               3  ...         9.200000                       5
# 39998               2  ...        17.600000                       5
# 39999               1  ...        25.200001                       4
#
#        Product_Reviews_Written  Social_Media_Engagement_Score  \
# 0                            3                            NaN
# 1                            1                            NaN
# 2                            5                      85.900002
# 3                            2                      14.300000
# 4                            6                      68.800003
# ...                        ...                            ...
# 39995                        3                       3.200000
# 39996                        5                      15.400000
# 39997                        1                      20.700001
# 39998                        3                      38.599998
# 39999                        6                      59.900002
#
#        Mobile_App_Usage  Payment_Method_Diversity  Lifetime_Value  \
# 0             23.299999                         3     1067.469971
# 1              8.800000                      <NA>     1289.750000
# 2             31.000000                         3     2340.919922
# 3             11.200000                         2     1995.430054
# 4             42.900002                         5     3003.570068
# ...                 ...                       ...             ...
# 39995         12.900000                         5      917.830017
# 39996         14.600000                         2      813.109985
# 39997         25.200001                         1     2365.979980
# 39998         12.100000                         4     1293.599976
# 39999               NaN                         1     1655.280029
#
#        Credit_Balance  Churned  Signup_Quarter
# 0                3028        0              Q4
# 1                2317        0              Q4
# 2                2674        0              Q1
# 3                2418        1              Q1
# 4                2657        0              Q1
# ...               ...      ...             ...
# 39995            1298        1              Q4
# 39996            3565        1              Q2
# 39997            3499        0              Q2
# 39998            3154        0              Q3
# 39999            1622        0              Q1
#
# [40000 rows x 25 columns]

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %% [markdown]
# ### Dividing the data into categories
# #### Demographics
# * Age
# * Gender
# * Country
# * City
# * Membership_Years
# * Signup_Quarter
#
# #### Engagement / Behavior
# * Login_Frequency
# * Session_Duration_Avg
# * Pages_Per_Session
# * Email_Open_Rate
# * Mobile_App_Usage
# * Social_Media_Engagement_Score
#
# ### Purchase / Transaction
# * Total_Purchases
# * Average_Order_Value
# * Discount_Usage_Rate
# * Returns_Rate
# * Wishlist_Items
# * Cart_Abandonment_Rate
# * Days_Since_Last_Purchase
# * Payment_Method_Diversity
#
# ### Value/Loyalty
# * Lifetime_Value
# * Credit_Balance
# * Product_Reviews_Written
# * Customer_Service_Calls
#
# ### Target
# * Churned

# %%
# demographics = ["Age","Gender","Country","City","Membership_Years","Signup_Quarter"]
# behavior = ["Login_Frequency","Session_Duration_Avg","Pages_Per_Session","Email_Open_Rate","Mobile_App_Usage","Social_Media_Engagement_Score"]
# transaction = ["Total_Purchases","Average_Order_Value","Discount_Usage_Rate","Returns_Rate","Wishlist_Items","Cart_Abandonment_Rate","Days_Since_Last_Purchase","Payment_Method_Diversity"]
# loyalty = ["Lifetime_Value","Credit_Balance","Product_Reviews_Written","Customer_Service_Calls"]
# target = ["Churned"]

# %% [markdown]
# ### Demographics - EDA - Univariate

# %%
class UnivariateAnalysis():
    def __init__(self,df,types):
        self.df = df
        self.types = types
        self.numeric = []
        self.category = []

        
    def divide_cols(self):
        for col in self.types:
            if pd.api.types.is_numeric_dtype(self.df[col]):
                self.numeric.append(col)

            elif pd.api.types.is_categorical_dtype(self.df[col]):
                self.category.append(col)

    def numeric_analysis(self):
        for col in self.numeric:
            fig,axes = plt.subplots(1,2,figsize=(10,4))
            sns.histplot(data = self.df,x=col,ax=axes[0])
            axes[0].set_title(f"Histogram of {col}")
            sns.boxplot(data = self.df,x=col,ax=axes[1])
            axes[1].set_title(f"Boxplot of {col}")
            
            plt.show()

    def category_analysis(self):
        for col in self.category:
            plt.figure(figsize=(8,4))
            sns.countplot(data=self.df,x=col)
            plt.title(f"Countplot of {col}")
            plt.xticks(rotation = 45)
            plt.show()

    def show(self):
        self.divide_cols()
        print(f"In this type {self.types}")
        print(f"Numerical columns are {self.numeric}")
        print(f"Categorical columns are {self.category}")
        return self.numeric_analysis(), self.category_analysis()

# %%
# if the col is continuous
# check skewness
# check outliers
# check distribution
# check normality
# check missingness
# check outliers

# if the col is discrete
# frequency distribution
# dominant counts
# zero heavy
# imbalance
# missing
# outliers

# if the col is categorical
# missing
# unique count
# top catgories
# category percentages
# rare categories

# %%
l = []
for i in df.columns:
    if df[i].dtype == "float32":
        l.append(i)
l
c = []
for i in df.columns:
    if df[i].dtype == "category":
        c.append(i)
c
# Out:
# ['Gender', 'Country', 'City', 'Signup_Quarter']

# %%
class UniInsights():
    def __init__(self,df,col):
        self.df = df
        self.col = col
        self.continuous_cols = ["Age",'Membership_Years','Session_Duration_Avg',
                                'Pages_Per_Session','Cart_Abandonment_Rate','Total_Purchases','Average_Order_Value',
                                'Discount_Usage_Rate','Returns_Rate','Email_Open_Rate','Social_Media_Engagement_Score',
                                'Mobile_App_Usage','Lifetime_Value','Days_Since_Last_Purchase','Credit_Balance',"Login_Frequency","Wishlist_Items",
                                "Customer_Service_Calls","Product_Reviews_Written",]
        
        self.discrete_cols = ["Payment_Method_Diversity"]
        self.categorical_cols = ['Churned','Gender', 'Country', 'City', 'Signup_Quarter']

    def missing_values(self):
        missing = self.df[self.col].isna().sum()
        size = len(self.df)
        missing_percentage = (missing/size) * 100
        return missing_percentage

    def outliers(self):
        q1 = self.df[self.col].quantile(0.25)
        q3 = self.df[self.col].quantile(0.75)
        iqr = q3 - q1
        low_whisker = q1 - 1.5 * iqr
        high_whisker = q3 + 1.5 * iqr
        print("low whisker",low_whisker)
        print("high_whisker",high_whisker)
        data = self.df[self.col].dropna()
        outliers = ((self.df[self.col] < low_whisker) | (self.df[self.col] > high_whisker)).sum()
        outliers_percentage = (outliers/len(data)) * 100
        return outliers_percentage
        
    
    def categorical_analysis(self):
        print("Unique values:", self.df[self.col].nunique())
        print(self.df[self.col].value_counts(normalize=True)*100)
            
    def discrete_analysis(self):
        print("Unique values:", self.df[self.col].nunique())
        print(self.df[self.col].value_counts().sort_index())


    
    def continuous_analysis(self):
        print("Mean:", self.df[self.col].mean())
        print("Median:", self.df[self.col].median())
        print("Performing dip test..........")
        # as dip test wont work for NA or NAN
        # dip test null hypothesis - the data comes from a unimodal distribution
        # dip test alternate hypothesis - the data comes from multi modal
        temp_col = self.df[self.col].dropna()
        dip,p_value = diptest(temp_col)
        if p_value < 0.05:
            print("Reject H0, that is data is multimodal")
        else:
            print("Data comes from unimodal")
        skewness = self.df[self.col].skew()
        print("Skewness:", skewness)
        if skewness >= -0.5 and skewness <= 0.5:
            print("Approximately Symmetric distribution")
        elif skewness > 0.5:
            print("Positively skewed")
        else:
            print("Negatively skewed")
        print("Min:", self.df[self.col].min())
        print("Max:", self.df[self.col].max())
        
    def flow(self):
        print(f"The column is {self.col}")
        missing_per = self.missing_values()
        print(f"Missing percentage: {missing_per}")
        if self.col in self.categorical_cols:
            self.categorical_analysis()
        elif self.col in self.discrete_cols:
            # outliers_per = self.outliers()
            # print(f"Outliers percentage {outliers_per}")
            self.discrete_analysis()
        else:
            outliers_per = self.outliers()
            print(f"Outliers percentage {outliers_per}")
            self.continuous_analysis()

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(data=df,x="Churned",width=0.5)
for bar in ax.patches: # looping through each bar one by one
    count = bar.get_height() # gets the raw height
    percentage = (count/len(df))*100
    # ax.text(x_position,y_position,text)
    ax.text(bar.get_x() + bar.get_width()/2 ,count+225,f"{percentage:.1f}%",ha="center")
plt.title("Churned")
plt.xlabel("Churned")
plt.ylabel("Count")
plt.show()
insights_gender = UniInsights(df,"Churned")
insights_gender.flow()
# dir(ax)
# dir(bar)
# Out:
# The column is Churned
# Missing percentage: 0.0
# Unique values: 2
# Churned
# 0    63.875
# 1    36.125
# Name: proportion, dtype: float64

# %% [markdown]
# ### Insights
# * This is the target column used for churn prediction.
# * As we can see, it is moderately imbalanced.
# * why this matters, because imbalance affects in model learning, evaluation metrics and prediction quality.
# * so here, we need to catch as many churners as possible, so even a person who is not having high probability of churning is marked as high, this is okay, but if a person is about to churn but it is marked as medium or low, then it is a problem, so use recall.
# * false negatives are more dangerous here.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Age",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Age")
axes[0].set_xlabel("Age")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Age",ax=axes[1])
axes[1].set_title("Boxplot for Age")
axes[1].set_xlabel("Age")

plt.show()

insights_age = UniInsights(df,"Age")
insights_age.flow()
# Out:
# The column is Age
# Missing percentage: 4.8925
# low whisker 5.0
# high_whisker 69.0
# Outliers percentage 0.38903346213495255
# Mean: 37.58604736745262
# Median: 37.0
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 0.9145309937060391
# Positively skewed
# Min: 5
# Max: 200

# %% [markdown]
# ### Insights for Age feature
# * Most customers fall betweem the age range of 20-50, with the highest concentration aroung 35-40 and gradual decline after 50, indicates very few elderly/extreme ages customers are there.
# * The distribution appears slightly positively skewed due to the presence of higher age values.
# * There are outliers, the max age is 200, which is not so possible in real life
# * Min age is 5 is also unrealistic for an independent ecommerce customer
# * mean and median are close, what does it mean??
# * even though mean and median are close, the dip test says not unimodal
# * that means the data may still have two peaks/groups
# * but overall balance between left/right side is still maintained.

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(data=df,x="Gender",width=0.5)
for bar in ax.patches: # looping through each bar one by one
    count = bar.get_height() # gets the raw height
    percentage = (count/len(df))*100
    # ax.text(x_position,y_position,text)
    ax.text(bar.get_x() + bar.get_width()/2 ,count+225,f"{percentage:.1f}%",ha="center")
plt.title("Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
insights_gender = UniInsights(df,"Gender")
insights_gender.flow()
# dir(ax)
# dir(bar)
# Out:
# The column is Gender
# Missing percentage: 0.0
# Unique values: 3
# Gender
# Female    50.140
# Male      47.985
# Other      1.875
# Name: proportion, dtype: float64

# %% [markdown]
# ### Insights for Gender feature
# * No missing values are present in the Gender feature.
# * The feature contains 3 unique categories.
# * Whereas male and female genders are nearly equally distributed.
# * The other cetagory represents a very small portion of the dataset(1.88%)

# %%
order = df["Country"].value_counts().index
plt.figure(figsize=(6,4))
ax = sns.countplot(data=df,x="Country",width=0.8,order=order)
for bar in ax.patches: # looping through each bar one by one
    count = bar.get_height() # gets the raw height
    percentage = (count/len(df))*100
    # ax.text(x_position,y_position,text)
    ax.text(bar.get_x() + bar.get_width()/2 ,count+200,f"{percentage:.1f}%",ha="center")
plt.title("Country")
plt.xlabel("Country")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
insights_gender = UniInsights(df,"Country")
insights_gender.flow()
# dir(ax)
# dir(bar)
# Out:
# The column is Country
# Missing percentage: 0.0
# Unique values: 8
# Country
# USA          34.6825
# UK           14.9800
# Canada       12.0350
# Germany       9.8900
# Australia     8.2675
# France        8.0750
# India         6.9075
# Japan         5.1625
# Name: proportion, dtype: float64

# %%
order = df["City"].value_counts().head(10).index
plt.figure(figsize=(7,4))
ax = sns.countplot(data=df,x="City",width=0.7,order = order)
for bar in ax.patches: # looping through each bar one by one
    count = bar.get_height() # gets the raw height
    percentage = (count/len(df))*100
    # ax.text(x_position,y_position,text)
    # ax.text(count+220,bar.get_y() + bar.get_height()/2 ,f"{percentage:.1f}%",va="center")
    ax.text(bar.get_x() + bar.get_width()/2 ,count+30,f"{percentage:.1f}%",ha="center")
plt.title("Top 10 cities")
plt.xlabel("City")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
insights_gender = UniInsights(df,"City")
insights_gender.flow()
# dir(ax)
# dir(bar)
# Out:
# The column is City
# Missing percentage: 0.0
# Unique values: 40
# City
# Houston        7.0625
# Phoenix        6.9825
# Chicago        6.9525
# New York       6.8975
# Los Angeles    6.7875
# Manchester     3.1650
# Leeds          3.0325
# Birmingham     3.0225
# London         2.9275
# Glasgow        2.8325
# Montreal       2.4700
# Ottawa         2.4000
# Toronto        2.3925
# Calgary        2.3875
# Vancouver      2.3850
# Hamburg        2.0775
# Cologne        2.0625
# Berlin         2.0275
# Munich         1.9275
# Frankfurt      1.7950
# Sydney         1.6825
# Perth          1.6775
# Toulouse       1.6525
# Brisbane       1.6500
# Adelaide       1.6425
# Nice           1.6325
# Lyon           1.6275
# Melbourne      1.6150
# Marseille      1.5900
# Paris          1.5725
# Chennai        1.5025
# Mumbai         1.3775
# Bangalore      1.3550
# Delhi          1.3450
# Hyderabad      1.3275
# Tokyo          1.1025
# Kyoto          1.0675
# Nagoya         1.0075
# Osaka          1.0000
# Yokohama       0.9850
# Name: proportion, dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'City', 'Membership_Years',
#        'Login_Frequency', 'Session_Duration_Avg', 'Pages_Per_Session',
#        'Cart_Abandonment_Rate', 'Wishlist_Items', 'Total_Purchases',
#        'Average_Order_Value', 'Days_Since_Last_Purchase',
#        'Discount_Usage_Rate', 'Returns_Rate', 'Email_Open_Rate',
#        'Customer_Service_Calls', 'Product_Reviews_Written',
#        'Social_Media_Engagement_Score', 'Mobile_App_Usage',
#        'Payment_Method_Diversity', 'Lifetime_Value', 'Credit_Balance',
#        'Churned', 'Signup_Quarter'],
#       dtype='object')

# %%
discrete_cols = [
    "Login_Frequency",
    "Wishlist_Items",
    "Customer_Service_Calls",
    "Product_Reviews_Written",
    "Payment_Method_Diversity"]
# the first 4 features contain relatively higher unique discrete values,
# so histogram with discrete=True are used to better visualize their distributions.
# Payment method has very low cardinality (only a few unique values)
# so a countplot is more suitable for visualizing category frequencies
# i can also use count plots for all the features, but as there are more unique counts
# However, for features
# with higher cardinality, histograms provide cleaner distribution visualization
# and help in understanding skewness and overall distribution shape.
# so i changed the lists in UniInsights class

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Membership_Years",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Membership_Years")
axes[0].set_xlabel("Membership_Years")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Membership_Years",ax=axes[1])
axes[1].set_title("Boxplot for Membership_Years")
axes[1].set_xlabel("Membership_Years")

plt.show()

insights_age = UniInsights(df,"Membership_Years")
insights_age.flow()
# Out:
# The column is Membership_Years
# Missing percentage: 0.0
# low whisker -2.6499999165534973
# high_whisker 8.149999797344208
# Outliers percentage 2.8375
# Mean: 2.9884396
# Median: 2.5
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 1.132526
# Positively skewed
# Min: 0.1
# Max: 10.0

# %% [markdown]
# ### Insights
# * From the histogram
# * Most customers have lower membership years.
# * Freq gradually decreases as membership years increases.
# * Distribution is clearly possitively skewed
# * Many values small
# * Long right tail
# * Also we saw mean = 2.9 > median 2.5 which also indicates positively skewed.
# * The boxplot show
# * several high-end outliers aroung 8-10 years
# * they are like long term loyal customers
# * So business wise - these may actually be valuable customers, not bad data
# * so dont remove them blindly - for me
# * Imp issuse is diptest says data is multimodal, but visually it is unimodal+skewed
# * This can happen because
# * large datasets are very sensitive
# * dip test detects even tiny deviations
# * skewed distributions sometimes trigger significance

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Session_Duration_Avg",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Session_Duration_Avg")
axes[0].set_xlabel("Session_Duration_Avg")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Session_Duration_Avg",ax=axes[1])
axes[1].set_title("Boxplot for Session_Duration_Avg")
axes[1].set_xlabel("Session_Duration_Avg")

plt.show()

insights_age = UniInsights(df,"Session_Duration_Avg")
insights_age.flow()
# Out:
# The column is Session_Duration_Avg
# Missing percentage: 7.145
# low whisker -3.6000004
# high_whisker 57.200005
# Outliers percentage 0.6057832103817781
# Mean: 27.267181
# Median: 26.3
# Performing dip test..........
# Data comes from unimodal
# Skewness: 0.4079338
# Approximately Symmetric distribution
# Min: 1.0
# Max: 75.6

# %% [markdown]
# ### Insights
# * The Session_Duration_Avg feature contains approximately 7.15% missing values.
# * The distribution appears unimodal with a single dominant peak.
# * The feature shows an approximately symmetric distribution with slight positive skewness (Skewness ≈ 0.41).
# * Mean (27.27) and median (26.3) are relatively close, further indicating near-symmetric behavior.
# * Most customers have moderate session durations, while extremely high session durations are comparatively less frequent.
# * Approximately 0.61% of observations are identified as outliers, primarily on the higher end of the distribution.
# * Customers with longer session durations may indicate higher engagement levels and stronger interaction with the platform.
# * Since the feature is relatively well-distributed with limited outliers, extensive transformation may not be necessary before modeling.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Pages_Per_Session",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Pages_Per_Session")
axes[0].set_xlabel("Pages_Per_Session")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Pages_Per_Session",ax=axes[1])
axes[1].set_title("Boxplot for Pages_Per_Session")
axes[1].set_xlabel("Pages_Per_Session")

plt.show()

insights_age = UniInsights(df,"Pages_Per_Session")
insights_age.flow()
# Out:
# The column is Pages_Per_Session
# Missing percentage: 5.9775
# low whisker -2.15
# high_whisker 19.050001
# Outliers percentage 0.5610359222526523
# Mean: 8.60983
# Median: 8.3
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 0.39782694
# Approximately Symmetric distribution
# Min: 1.0
# Max: 24.1

# %% [markdown]
# ### Insights for Pages_Per_Session Feature
# * The feature contains approximately 5.98% missing values.
# * The distribution appears approximately unimodal with a single dominant peak.
# * The feature shows slight positive skewness (Skewness ≈ 0.40) but remains approximately symmetric overall.
# * Mean (8.61) and median (8.3) are relatively close, supporting near-symmetric behavior.
# * Most customers visit a moderate number of pages per session, while very high page counts are less common.
# * Approximately 0.56% of observations are identified as high-end outliers.
# * Customers with higher pages per session may indicate stronger browsing behavior and platform engagement.
# * The feature appears reasonably well-distributed and may not require heavy transformation before modeling.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Cart_Abandonment_Rate",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Cart_Abandonment_Rate")
axes[0].set_xlabel("Cart_Abandonment_Rate")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Cart_Abandonment_Rate",ax=axes[1])
axes[1].set_title("Boxplot for Cart_Abandonment_Rate")
axes[1].set_xlabel("Cart_Abandonment_Rate")

plt.show()

insights_age = UniInsights(df,"Cart_Abandonment_Rate")
insights_age.flow()
# Out:
# The column is Cart_Abandonment_Rate
# Missing percentage: 0.0
# low whisker 12.850006103515625
# high_whisker 103.64999389648438
# Outliers percentage 0.6125
# Mean: 57.782463
# Median: 58.8
# Performing dip test..........
# Data comes from unimodal
# Skewness: -0.26235375
# Approximately Symmetric distribution
# Min: 0.0
# Max: 143.74335

# %% [markdown]
# ### Insights
# #### main thing is this is percentage of cart_abandonment_rate, but here max value is 143 which is exceeding 100 which may indicate data quality issues, scaling inconsistencies, or synthetic data generation artifacts.
# * No missing values are present in the feature.
# * The distribution appears approximately unimodal and symmetric.
# * Mean (57.78) and median (58.8) are relatively close, supporting near-symmetric behavior.
# * Skewness (-0.26) indicates only slight negative skewness.
# * Approximately 0.61% of observations are identified as outliers on both lower and higher ends.
# * Most customers exhibit moderate cart abandonment behavior centered around the middle range.
# * Extremely high abandonment rates may indicate checkout friction, low purchase intent, or browsing-focused behavior.
# * Values exceeding 100 are observed, which may indicate potential data inconsistencies or synthetic data artifacts and should be validated before modeling.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Total_Purchases",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Total_Purchases")
axes[0].set_xlabel("Total_Purchases")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Total_Purchases",ax=axes[1])
axes[1].set_title("Boxplot for Total_Purchases")
axes[1].set_xlabel("Total_Purchases")

plt.show()

insights_age = UniInsights(df,"Total_Purchases")
insights_age.flow()
# Out:
# The column is Total_Purchases
# Missing percentage: 0.0
# low whisker -5.34999942779541
# high_whisker 30.249999046325684
# Outliers percentage 1.2349999999999999
# Mean: 12.926246
# Median: 12.0
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 2.4730644
# Positively skewed
# Min: -13.0
# Max: 127.4

# %%
df["Total_Purchases"].nlargest(2)
# Out:
# 36494    127.400002
# 31230    124.800003
# Name: Total_Purchases, dtype: float32

# %% [markdown]
# ### Insights
# * Most customers have relatively lower purchase counts.
# * Outliers exist mainly on: higher purchase side
# * These may represent:
# * loyal customers
# * premium customers
# * bulk buyers
# * highly engaged users
# * And one more imp point to notice is min value is -13.0 as total purchases  cannot be negative, but it can be special cases of handling such as refunds/returns.
# * Further validation of negative values should be performed before model building.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Average_Order_Value",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Average_Order_Value")
axes[0].set_xlabel("Average_Order_Value")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Average_Order_Value",ax=axes[1])
axes[1].set_title("Boxplot for Average_Order_Value")
axes[1].set_xlabel("Average_Order_Value")

plt.show()

insights_age = UniInsights(df,"Average_Order_Value")
insights_age.flow()
# Out:
# The column is Average_Order_Value
# Missing percentage: 0.0
# low whisker 0.40874290466308594
# high_whisker 233.65875816345215
# Outliers percentage 1.9924999999999997
# Mean: 125.136536
# Median: 113.96
# Performing dip test..........
# Data comes from unimodal
# Skewness: 39.224022
# Positively skewed
# Min: 26.87
# Max: 9666.379

# %%
df["Average_Order_Value"].nlargest(2)
# Out:
# 9033    9666.378906
# 2511    9487.427734
# Name: Average_Order_Value, dtype: float32

# %% [markdown]
# ### Insights
# * Average_Order_Value shows a highly positively skewed distribution with a small percentage of extreme high-value purchases.
# * Most customers place low-to-moderate value orders, while a few premium customers contribute disproportionately high revenue.
# * Around 1.99% of observations were identified as outliers using the IQR method.
# * The feature may require transformation or robust scaling for certain machine learning models.

# %% [markdown]
# ### Combined insights on Total purchases and average order value
# * Total_Purchases --- buying frequency/intensity
# * Average_Order_Value --- spending per order
# * One customer may buy many cheap products.
# * Another may buy few expensive products
# * Companies track both features seperately.
# * the presence of continuous values in Total_Purchases suggests that the feature may represent transformed or synthetically generated purchase behavior rather than raw order counts.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Discount_Usage_Rate",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Discount_Usage_Rate")
axes[0].set_xlabel("Discount_Usage_Rate")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Discount_Usage_Rate",ax=axes[1])
axes[1].set_title("Boxplot for Discount_Usage_Rate")
axes[1].set_xlabel("Discount_Usage_Rate")

plt.show()

insights_age = UniInsights(df,"Discount_Usage_Rate")
insights_age.flow()
# Out:
# The column is Discount_Usage_Rate
# Missing percentage: 6.915
# low whisker -22.62
# high_whisker 104.58
# Outliers percentage 0.22291454047376055
# Mean: 41.74135
# Median: 39.9
# Performing dip test..........
# Data comes from unimodal
# Skewness: 0.3812094
# Approximately Symmetric distribution
# Min: 0.5
# Max: 116.16

# %% [markdown]
# ### Insights
# * The feature contains approximately 6.92% missing values.
# * The distribution appears unimodal and approximately symmetric with slight positive skewness (Skewness ~ 0.38).
# * Mean (41.74) and median (39.9) are relatively close, indicating near-symmetric behavior.
# * Most customers exhibit moderate discount usage behavior.
# * Approximately 0.22% of observations are identified as high-end outliers.
# * Values exceeding 100 are observed (Max = 116.16), which may indicate potential data inconsistencies, synthetic data artifacts, or non-standard feature scaling since percentage-based metrics are typically bounded between 0 and 100.
# * Customers with high discount usage may represent price-sensitive users who rely heavily on promotional offers.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Returns_Rate",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Returns_Rate")
axes[0].set_xlabel("Returns_Rate")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Returns_Rate",ax=axes[1])
axes[1].set_title("Boxplot for Returns_Rate")
axes[1].set_xlabel("Returns_Rate")

plt.show()

insights_age = UniInsights(df,"Returns_Rate")
insights_age.flow()
# Out:
# The column is Returns_Rate
# Missing percentage: 8.955
# low whisker -6.5499997
# high_whisker 18.65
# Outliers percentage 2.498764347300785
# Mean: 6.720104
# Median: 5.5
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 5.7907104
# Positively skewed
# Min: 0.0
# Max: 99.61573

# %% [markdown]
# ### Insights
# * Most customers have low return rates.
# * Few customers have extremely high return behavior.
# * High return-rate customers may represent, dissatisfied users, product mismatch users, this can become a strong churn signal.
# * So here i can observed behavirol segments/groups in the distribution(3).
# * 0-15 is the main dense clutter, these custoemrs rarely return products, likely satisfied and it is a normal buying behavior.
# * 20-35 is group 2 which is moderate returners
# * Smaller outlier group, occasional dissatisfaction, size mismatch or selective returns.
# * Group 3 extreme returners
# * chronic returners
# * fraud behavior
# * highly dissatisfied customers
# * trail-based shopping behavior

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Email_Open_Rate",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Email_Open_Rate")
axes[0].set_xlabel("Email_Open_Rate")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Email_Open_Rate",ax=axes[1])
axes[1].set_title("Boxplot for Email_Open_Rate")
axes[1].set_xlabel("Email_Open_Rate")

plt.show()

insights_age = UniInsights(df,"Email_Open_Rate")
insights_age.flow()
# Out:
# The column is Email_Open_Rate
# Missing percentage: 5.1499999999999995
# low whisker -22.249998
# high_whisker 61.35
# Outliers percentage 0.4665260938323669
# Mean: 20.427364
# Median: 19.2
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 0.5151788
# Positively skewed
# Min: 0.0
# Max: 85.7

# %% [markdown]
# ### Insights
# * Large spike near 0
# * Main concentration around 10–30
# * Gradual decrease toward higher values
# * Long right tail
# * This suggests there are different types of customers:
# * Customers who rarely open emails
# * Moderately engaged customers
# * Highly engaged customers
# * Because customer email behavior is usually segmented into groups:
# * inactive users
# * casual users
# * loyal/engaged users
# * Not everyone interacts with marketing emails similarly.
# * large concentration of customers near zero email engagement may represent a potential churn-risk segment requiring targeted re-engagement campaigns.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Social_Media_Engagement_Score",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Social_Media_Engagement_Score")
axes[0].set_xlabel("Social_Media_Engagement_Score")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Social_Media_Engagement_Score",ax=axes[1])
axes[1].set_title("Boxplot for Social_Media_Engagement_Score")
axes[1].set_xlabel("Social_Media_Engagement_Score")

plt.show()

insights_age = UniInsights(df,"Social_Media_Engagement_Score")
insights_age.flow()
# Out:
# The column is Social_Media_Engagement_Score
# Missing percentage: 11.97
# low whisker -32.9
# high_whisker 87.899994
# Outliers percentage 0.519709190048847
# Mean: 28.76833
# Median: 26.8
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 0.52429044
# Positively skewed
# Min: 0.0
# Max: 100.0

# %% [markdown]
# ### Insights
# * Main point is missing percentage is 11.97%, it maybe due to many reasons, like are inactive users not generating engagement data?
# * is tracking failing for some users?
# * are some customers not connected to social accounts?
# * is missingness itself related to churn?
# * if we can see the below cell, the missingness in this column does not appear to have a strong relationship with churn, as churn rates between missing and non-missing groups are relatively similar.
# * This suggests the missing values may be random or operational(api problen, tracking problem, system bug, data sync issue) rather than behaviorally driven.
# * It shows a multimodal distribution, indicating the presence of multiple customer engagement groups ranging from inactive to highly engaged users.
# * The feature is mildly positive skewed with very few high-end outliers, suggesting stable behavior overall
# * A significant concentration of low-engagement customers is observed near zero, which may indicate a potential high-risk churn segment requiring targeted engagement strategies.

# %%
df.groupby(df["Social_Media_Engagement_Score"].isnull())["Churned"].mean()
# Out:
# Social_Media_Engagement_Score
# False    0.359792
# True     0.371972
# Name: Churned, dtype: float64

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Mobile_App_Usage",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Mobile_App_Usage")
axes[0].set_xlabel("Mobile_App_Usage")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Mobile_App_Usage",ax=axes[1])
axes[1].set_title("Boxplot for Mobile_App_Usage")
axes[1].set_xlabel("Mobile_App_Usage")

plt.show()

insights_age = UniInsights(df,"Mobile_App_Usage")
insights_age.flow()
# Out:
# The column is Mobile_App_Usage
# Missing percentage: 9.959999999999999
# low whisker -7.550001
# high_whisker 44.850002
# Outliers percentage 0.6219458018658374
# Mean: 19.041996
# Median: 18.2
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 0.41720268
# Approximately Symmetric distribution
# Min: 0.0
# Max: 61.9

# %% [markdown]
# ### Insights
# * In customer behavior type, this feature is good
# * Unlike email open rate and social media engagement score this feature does not have a huge spike at 0
# * Meaning many customers are at least somewhat active on app.
# * App adoption is reasonably good
# * that is actually a positive business sign.
# * The absence of a large inactive cluster near zero suggests healthy mobile platform adoption among customers, while lower usage levels may still indicate potential churn risk.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Lifetime_Value",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Lifetime_Value")
axes[0].set_xlabel("Lifetime_Value")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Lifetime_Value",ax=axes[1])
axes[1].set_title("Boxplot for Lifetime_Value")
axes[1].set_xlabel("Lifetime_Value")

plt.show()

insights_age = UniInsights(df,"Lifetime_Value")
insights_age.flow()
# Out:
# The column is Lifetime_Value
# Missing percentage: 0.0
# low whisker -930.7062454223633
# high_whisker 3607.423698425293
# Outliers percentage 2.91
# Mean: 1439.5131
# Median: 1235.065
# Performing dip test..........
# Data comes from unimodal
# Skewness: 1.3994877
# Positively skewed
# Min: 0.0
# Max: 8987.24

# %% [markdown]
# ### Insights
# * This feature is very useful for churn
# * Low LTV(Life time value) customer churns --> small loss
# * High LTV customer churns --> Huge business loss
# * Revenue at risk = churn probability * lifetime_value
# * Lifetime_Value exhibits a unimodal but positively skewed distribution, indicating that while most customers contribute moderate revenue, a smaller segment of high-value customers contributes disproportionately larger revenue.
# * Approximately 2.9% of customers fall into the high-value outlier range, likely representing premium or loyal customers.
# * Retaining these customers is business-critical due to their significant impact on overall revenue and churn-related financial risk.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Days_Since_Last_Purchase",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Days_Since_Last_Purchase")
axes[0].set_xlabel("Days_Since_Last_Purchase")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Days_Since_Last_Purchase",ax=axes[1])
axes[1].set_title("Boxplot for Days_Since_Last_Purchase")
axes[1].set_xlabel("Days_Since_Last_Purchase")

plt.show()

insights_age = UniInsights(df,"Days_Since_Last_Purchase")
insights_age.flow()
# Out:
# The column is Days_Since_Last_Purchase
# Missing percentage: 6.0125
# low whisker -40.5
# high_whisker 91.5
# Outliers percentage 4.987365341135789
# Mean: 30.559090304561778
# Median: 21.0
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 1.9582533814460577
# Positively skewed
# Min: 0
# Max: 287

# %% [markdown]
# ### Insights
# * Days since last purchases basically tellls
# * how long it has been since the customer last made a purchase.
# * this is a classic recency feature - means, how recently a customer performed an activity.
# * what is recency?
# * quality of being new, fresh or having occured a short time ago.
# * in customer analytics, recency is extremely powerful.
# * based on the histogram, most customers purchased recently.
# * fewer customers have been inactive for a long time.
# * the outliers percentage is slightly higher than the previous featured we analysed until now.
# * but here it is very realistic for recency data.
# * The multimodal behavior suggests the presence of distinct activity segments such as active, occasional, and inactive buyers.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Credit_Balance",color="cornflowerblue",kde=True,bins=50,ax=axes[0])
axes[0].set_title("Frequency Distribution of Credit_Balance")
axes[0].set_xlabel("Credit_Balance")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Credit_Balance",ax=axes[1])
axes[1].set_title("Boxplot for Credit_Balance")
axes[1].set_xlabel("Credit_Balance")

plt.show()

insights_age = UniInsights(df,"Credit_Balance")
insights_age.flow()
# Out:
# The column is Credit_Balance
# Missing percentage: 11.085
# low whisker -1616.0
# high_whisker 5384.0
# Outliers percentage 0.49204296237980094
# Mean: 1935.1566102457402
# Median: 1862.0
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 0.3999061728903751
# Approximately Symmetric distribution
# Min: 0
# Max: 7160

# %%
pd.cut(df["Credit_Balance"], 4)
# Out:
# 0        (1790.0, 3580.0]
# 1        (1790.0, 3580.0]
# 2        (1790.0, 3580.0]
# 3        (1790.0, 3580.0]
# 4        (1790.0, 3580.0]
#                ...
# 39995     (-7.16, 1790.0]
# 39996    (1790.0, 3580.0]
# 39997    (1790.0, 3580.0]
# 39998    (1790.0, 3580.0]
# 39999     (-7.16, 1790.0]
# Name: Credit_Balance, Length: 40000, dtype: category
# Categories (4, interval[float64, right]): [(-7.16, 1790.0] < (1790.0, 3580.0] < (3580.0, 5370.0] < (5370.0, 7160.0]]

# %%
df.groupby(pd.qcut(df["Credit_Balance"], 4))["Churned"].mean()
# (-0.001, 1009.0]  here min value is 0 as we see above, but pandas adds a tuny negative value to make sure the min point is included properly
# Out:
# C:\Users\91891\AppData\Local\Temp\ipykernel_7956\880108798.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.qcut(df["Credit_Balance"], 4))["Churned"].mean()
# Credit_Balance
# (-0.001, 1009.0]    0.483755
# (1009.0, 1862.0]    0.371586
# (1862.0, 2759.0]    0.316453
# (2759.0, 7160.0]    0.271040
# Name: Churned, dtype: float64

# %% [markdown]
# ### Insights
# * As credit balance increases, churn decreases

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Login_Frequency",color="cornflowerblue",discrete=True,kde=True,ax=axes[0])
axes[0].set_title("Frequency Distribution of Login_Frequency")
axes[0].set_xlabel("Login_Frequency")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Login_Frequency",ax=axes[1])
axes[1].set_title("Boxplot for Login_Frequency")
axes[1].set_xlabel("Login_Frequency")

plt.show()

insights_age = UniInsights(df,"Login_Frequency")
insights_age.flow()
# Out:
# The column is Login_Frequency
# Missing percentage: 0.0
# low whisker -11.5
# high_whisker 32.5
# Outliers percentage 0.815
# Mean: 11.359925
# Median: 11.0
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 0.5280164049357178
# Positively skewed
# Min: 0
# Max: 46

# %% [markdown]
# ### Insights
# * Huge spike at 0, it suggests that many inactive customers,
# * possible business meaning
# * dormant users - customers who have become inactive or barely active on the platform.
# * churn-prone users
# * users who stopped engagement
# * main avtive cluster is 5-18 logins, these are normal active users
# * long right tail(30-46) indicates pwoer users, highly engaged customers.
# * Login frequency may serve as a strong behavioral indicator for customer engagement and churn prediction.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Wishlist_Items",color="cornflowerblue",discrete=True,bins=50,kde=True,ax=axes[0])
axes[0].set_title("Frequency Distribution of Wishlist_Items")
axes[0].set_xlabel("Wishlist_Items")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Wishlist_Items",ax=axes[1])
axes[1].set_title("Boxplot for Wishlist_Items")
axes[1].set_xlabel("Wishlist_Items")

plt.show()

insights_age = UniInsights(df,"Wishlist_Items")
insights_age.flow()
# Out:
# The column is Wishlist_Items
# Missing percentage: 8.02
# low whisker -4.0
# high_whisker 12.0
# Outliers percentage 1.8101761252446182
# Mean: 4.203413785605567
# Median: 4.0
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 0.9495473613369102
# Positively skewed
# Min: 0
# Max: 28

# %% [markdown]
# ### Insights
# * most customers have 0-6 wishlist items - moderate wishlist usage.
# * long right tail indicates few customers with 15-28 items, this may represent, highly interested browsers, undecided customers or product explorers.
# * high wishlist + low purchases may indicate, price-sensitive customers, or the customers waiting for discounts.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Customer_Service_Calls",color="cornflowerblue",discrete=True,bins=50,kde=True,ax=axes[0])
axes[0].set_title("Frequency Distribution of Customer_Service_Calls")
axes[0].set_xlabel("Customer_Service_Calls")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Customer_Service_Calls",ax=axes[1])
axes[1].set_title("Boxplot for Customer_Service_Calls")
axes[1].set_xlabel("Customer_Service_Calls")

plt.show()

insights_age = UniInsights(df,"Customer_Service_Calls")
insights_age.flow()
# Out:
# The column is Customer_Service_Calls
# Missing percentage: 0.3275
# low whisker -2.0
# high_whisker 14.0
# Outliers percentage 0.2508214402167097
# Mean: 5.79721086558479
# Median: 6.0
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 0.41386789864450285
# Approximately Symmetric distribution
# Min: 0
# Max: 21

# %% [markdown]
# ### Insights
# * No of times a customer contacted customer support/service.
# * It can be anything like complaint calls, refund requests, delivery issues, payment issues, technical support.
# * customers contacting support excessively often: churn more.

# %%
figure,axes = plt.subplots(1,2,figsize=(12,4))
sns.histplot(data=df,x="Product_Reviews_Written",color="cornflowerblue",discrete=True,bins=50,kde=True,ax=axes[0])
axes[0].set_title("Frequency Distribution of Product_Reviews_Written")
axes[0].set_xlabel("Product_Reviews_Written")
axes[0].set_ylabel("Frequency")

sns.boxplot(data=df,x="Product_Reviews_Written",ax=axes[1])
axes[1].set_title("Boxplot for Product_Reviews_Written")
axes[1].set_xlabel("Product_Reviews_Written")

plt.show()

insights_age = UniInsights(df,"Product_Reviews_Written")
insights_age.flow()
# Out:
# The column is Product_Reviews_Written
# Missing percentage: 7.045
# low whisker -3.5
# high_whisker 8.5
# Outliers percentage 2.2537787101285565
# Mean: 2.7889032327470282
# Median: 2.0
# Performing dip test..........
# Reject H0, that is data is multimodal
# Skewness: 1.0498248819942586
# Positively skewed
# Min: 0
# Max: 16

# %% [markdown]
# ### Insights
# * Number of product reviews submitted by a customer.
# * rating products
# * writing feedback
# * sharing opinions after purchase
# * this feature vs churn analysis becomes important, as it can be both ways, if a customer loves a product so much they will write a review, or if there are frustrated about the product also can write the review.

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(data=df,x="Payment_Method_Diversity",width=0.5)
for bar in ax.patches: # looping through each bar one by one
    count = bar.get_height() # gets the raw height
    percentage = (count/len(df))*100
    # ax.text(x_position,y_position,text)
    ax.text(bar.get_x() + bar.get_width()/2 ,count+150,f"{percentage:.1f}%",ha="center")
plt.title("Payment_Method_Diversity")
plt.xlabel("Payment_Method_Diversity")
plt.ylabel("Count")
plt.show()
insights_gender = UniInsights(df,"Payment_Method_Diversity")
insights_gender.flow()
# dir(ax)
# dir(bar)
# Out:
# The column is Payment_Method_Diversity
# Missing percentage: 5.0075
# Unique values: 5
# Payment_Method_Diversity
# 1     9411
# 2    13346
# 3     9502
# 4     3771
# 5     1967
# Name: count, dtype: Int64

# %% [markdown]
# ### Insights
# * Number of different payment methods used by a customer.
# * ex only upi
# * upi + credit card
# * upi+ card+wallet
# * most custoemrs are using 2 payment methods
# * very few customers use 4-5 methods
# * The feature may help capture customer behavioral flexibility and transaction preferences

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(data=df,x="Signup_Quarter",width=0.5)
for bar in ax.patches: # looping through each bar one by one
    count = bar.get_height() # gets the raw height
    percentage = (count/len(df))*100
    # ax.text(x_position,y_position,text)
    ax.text(bar.get_x() + bar.get_width()/2 ,count+100,f"{percentage:.1f}%",ha="center")
plt.title("Signup_Quarter")
plt.xlabel("Signup_Quarter")
plt.ylabel("Count")
plt.show()
insights_gender = UniInsights(df,"Signup_Quarter")
insights_gender.flow()
# dir(ax)
# dir(bar)
# Out:
# The column is Signup_Quarter
# Missing percentage: 0.0
# Unique values: 4
# Signup_Quarter
# Q2    25.230
# Q4    24.965
# Q1    24.910
# Q3    24.895
# Name: proportion, dtype: float64

# %% [markdown]
# ### Insights
# * Q1 - Jan-Mar
# * Q2 - Apr-Jun
# * Q3 - Jul-Sep
# * Q4 - Oct-Dec
# * In this data, all quarters are around, which means customers are almost equally distributed across signup periods.
# * this is a highly balanced categorical feature, as no quarter dominated strongly.
# * Further bivariate analysis with the target variable (Churned) is required to determine whether signup timing influences churn behavior
